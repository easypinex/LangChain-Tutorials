# %%
import sys
sys.path.append('..')

# %%
import os

from langchain_experimental.graph_transformers import LLMGraphTransformer
# from langchain_openai import ChatOpenAI
from langchain_openai import AzureChatOpenAI
from langchain_experimental.llms.ollama_functions import OllamaFunctions
llm = AzureChatOpenAI(
    azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"],
    azure_deployment=os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"],
    openai_api_version=os.environ["AZURE_OPENAI_API_VERSION"],
    temperature=0
)

# %%
from tools.logger import getLogger
logging = getLogger()

# %%
# from langchain_community.document_loaders import PyPDFLoader
from typing import List
from langchain_core.documents import Document
from tools.PDFTablePyPlumberLoader import PDFTablePyPlumberLoader
pages: List[List[Document]] = []
dir = '../data'
for filename in os.listdir(dir):
    if filename.endswith(".pdf"):
        if '個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版' not in filename:
            continue
        loader = PDFTablePyPlumberLoader(os.path.join(dir, filename), llm)
        pages += [loader.load()]
pages
# Out:
# Processing documents: 100%|██████████| 32/32 [00:36<00:00,  1.15s/it]
# [[Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 1}, page_content='資安等級：內部\n台灣人壽\n個人保險首/續期繳費暨保單貸款還款息作業手冊\n(113 年 7 月版)_業務通路版'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 2}, page_content='\n\n1. 配合實務作業，調整續期保險費採自行繳費作業之繳費管道說明。\n\n### 繳費管道變更與繳費日認定原則\n\n#### 原指定繳費管道：金融機構\n\n1. **改自行匯款**\n   - **於一照期限內完成**：是，於一照期限內完成匯款\n   - **繳費日認定原則**：可以用原授權書之申請日為繳費日\n   - **未於一照期限內完成**：否，未於一照期限內完成匯款\n   - **繳費日認定原則**：以實際匯款日為繳費日\n\n2. **改他行金融機構轉帳**\n   - **完成**：不限\n   - **繳費日認定原則**：可以用原授權書之申請日為繳費日\n\n3. **改信用卡**\n   - **完成**：不限\n   - **繳費日認定原則**：以新信用卡授權書之申請日為繳費日\n\n#### 原指定繳費管道：信用卡\n\n1. **改自行匯款**\n   - **完成**：不限\n   - **繳費日認定原則**：以實際匯款日為繳費日\n\n2. **改金融機構轉帳**\n   - **完成**：不限\n   - **繳費日認定原則**：以新金融機構轉帳授權書之申請日為繳費日\n\n3. **改同銀行其他信用卡或改他行信用卡**\n   - **完成**：不限\n   - **繳費日認定原則**：可以用原信用卡授權書之申請日為繳費日\n\n#### 註釋\n\n- **註1**：一照，意指核印/扣款失敗的第一次照會通知，期限為14天，或案件考量時效個別調整為7天者。\n- **註2**：停售商品變更繳費管道後之繳費日若等於或晚於商品停售日，應予以退件。\n\n### 繳費方式\n\n1. **金融機構轉帳**\n2. **信用卡繳費**\n3. **自行匯款**\n4. **支票**\n\n### 應檢附文件\n\n1. **金融機構轉帳**\n   - 保險費暨保險單\n   - 借款利息自動轉帳付款授權書\n2. **信用卡繳費**\n   - 保險費暨保險單\n   - 保險費信用卡付款授權書\n3. **自行匯款**\n   - 保險費暨保險單\n   - 匯款憑證\n4. **支票**\n   - 保險費暨保險單\n   - 支票\n\n### 文件檢附說明\n\n- V: 表示須檢附\n- X: 表示無須檢附\n\n### 保單關係人\n\n1. **身分/關係證明文件**\n   - 金融機構轉帳: X\n   - 信用卡繳費: X\n   - 自行匯款: X\n   - 支票: X\n2. **繳款聲明書**\n   - 金融機構轉帳: X\n   - 信用卡繳費: X\n   - 自行匯款:
'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 5}, page_content='(三) 生效日期之認定原則：依繳費方式或商品性質做認定\n1. 業務/保經/保代通路適用\n2. 電話行銷通路適用：請詳閱「新契約個人保險投保規則手冊-核保及行政篇」。\n六、 新契約首期保險費繳費管道異動之繳費日認定原則：\n(一) 新契約首期保險費繳費管道異動，應檢附「新契約要保內容變更申請書」及授權書 /繳費文\n件及相關證明文件。\n(二) 本項認定原則適用於：\n1. 為核保中主動變更繳費管道。\n2. 核印失敗或扣款失敗後變更繳費管道。\n(三) 以下表可以用原授權書之申請日認定為繳費日者，新授權書之申請日務必與原授權書之申\n請日一致，若不一致將以新授權書之申請日為繳費日。\n(四) 募集型商品、停售商品或個別商品若另有規定者從其約定，若未有另行約定則依下表規定\n辦理。\n七、 變更要保人時，須確認續期保險費授權人是否須辦理變更。\n\n### 首期保險費與保單生效日期之認定原則\n\n#### 繳費方式\n\n1. **金融機構自動轉帳**\n   - 壽險：以「自動轉帳授權書」之申請日期為準。\n   - 傷害險主約：以「自動轉帳授權書」之申請日期加1天為準。\n\n2. **信用卡扣款**\n   - 壽險：以「保險費信用卡付款授權書」之申請日期為準。\n   - 傷害險主約：以「保險費信用卡付款授權書」之申請日期加1天為準。\n\n3. **匯款件**\n   - 壽險：依繳款憑證上之交易日期為準。\n   - 傷害險主約：依繳款憑證上之交易日期加1天為準。\n\n#### 註\n\n- 信用卡扣款/金融機構自動轉帳：核保通過後始進行扣款/轉帳作業，且不得指定扣款/轉帳日期。'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 6}, page_content='貳、 繳款人相關規定\n一、 繳款人身分\n二、 繳費方式及受理應檢附文件\n\n保險費信用卡是一種用於支付保險費的信用卡。付款授權書是一種授權文件，允許特定的付款從指定的賬戶中扣除。\n\n### 繳款人身分說明\n\n#### 自然人\n\n- **保單關係人**：要保人、被保險人、受益人（係指於受益人指定欄位有載明人名之受益人）。\n- **非保單關係人**：要保人或被保險人之配偶、子女、父母、（外）祖父母、兄弟姐妹及法定代理人/監護人/輔助人。\n\n#### 法人\n\n- 法人、法人負責人及該企業員工。\n\n#### 境外匯款/OIU保單\n\n- 繳款人限保單關係人。\n\n保單是一種合同，通常由保險公司和投保人之間簽訂。保單詳細說明了保險公司在特定情況下支付給投保人或受益人的金額和條件。保單的主要目的是提供經濟保障，減少風險和不確定性。\n\n法人、法人負責人及該企業員工\n\n非保單：指不屬於保險單範疇的文件或資料。\n\n關係人：指與某特定事務或個體有直接或間接關聯的人士，可能包括家庭成員、商業夥伴或其他相關方。'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 7}, page_content='三、 自動轉帳及信用卡付款授權書作業規範【加強身分驗證機制】\n(一) 新契約投保時之自動轉帳及信用卡付款授權書(下稱授權書)，不得為空白授權且需依下列規\n範辦理：\n1. 投保當下已取得「保單號碼」者，行動投保件遞交時系統即產生保單號碼，請於授權書填\n寫「保單號碼」。\n2. 投保當下無法取得「保單號碼」者，授權書須填寫「授權書繳費號碼」，以足資連結保戶\n欲授權範圍。授權書填寫原則說明如下：\n(1) 一份要保書填寫一份授權書，不可多份要保書共同使用一份授權書。\n(2) 「授權書繳費號碼」不得重覆。\n(3) 授權書之「授權書繳費號碼」，須同時寫在「業務人員招攬報告書」上，且上述兩份表\n單之「授權書繳費號碼」必須一致。\n(4) 「授權書繳費號碼」之編碼規則為要保人 ID末4 碼＋要保書申請日之年月日(7 碼)＋\n時分(4 碼)，共計 15 碼。\n舉例：要保人 ID 末 4 碼為 1234，於 110 年 01 月 01 日 13 點 15 分填寫授權書，其\n「授權書繳費號碼」即為 1234-1100101-1315。\n3. 授權書未填寫「授權書繳費號碼」或「保單號碼」時，將照會重補授權書。'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number':
 自 106 年 01 月 16 日起新契約全面停止受理現金；自 106 年 07 月 01 日起新契約首期\n保險費以匯款方式繳交者，不再開立「壽險首期保險費送金單」。\n四、 首期保險費-採自行匯款管道\n(一) 台幣-首期匯款帳號【業務通路適用】\n※ 請將台幣首期保險費依轄屬分公司匯入以下指定台幣實體帳號。\n\n以下是台灣人壽保險股份有限公司各分公司的匯款資訊：\n\n### 台北分公司\n- **匯款戶名**：台灣人壽保險股份有限公司 台北分公司\n- **匯款銀行**：中國信託商業銀行 城中分行\n- **匯款帳號**：822-107118347202\n- **劃撥帳號**：1185-1115\n\n### 新竹分公司\n- **匯款戶名**：台灣人壽保險股份有限公司 新竹分公司\n- **匯款銀行**：土地銀行 新竹分行\n- **匯款帳號**：005-016-001-035413\n- **劃撥帳號**：0110-3183\n\n### 台中分公司\n- **匯款戶名**：台灣人壽保險股份有限公司 台中分公司\n- **匯款銀行**：中國信託商業銀行 台中分行\n- **匯款帳號**：822-026540322963\n- **劃撥帳號**：0021-9012\n\n### 嘉義分公司\n- **匯款戶名**：台灣人壽保險股份有限公司\n- **匯款銀行**：合作金庫 北嘉義分行\n- **匯款帳號**：006-1520717100015\n- **劃撥帳號**：0035-3812\n\n### 台南分公司\n- **匯款戶名**：台灣人壽保險股份有限公司 台南分公司\n- **匯款銀行**：中國信託商業銀行 西台南分行\n- **匯款帳號**：822-222118015202\n- **劃撥帳號**：0031-1131\n\n### 高雄分公司\n- **匯款戶名**：台灣人壽保險股份有限公司 高雄分公司\n- **匯款銀行**：台灣中小企業銀行 三民分行\n- **匯款帳號**：050-87012125575\n- **劃撥帳號**：0041-3321\n\n### 東部分公司\n- **匯款戶名**：台灣人壽保險股份有限公司 東部分公司\n- **匯款銀行**：元大銀行 花蓮分行\n- **匯款帳號**：806-20962000018558\n- **劃撥帳號**：0643-0636'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 12}, page_content='(二) 外幣-首期匯款帳號【業務通路適用】\n※ 共有 11 個虛擬帳號及1 個實體帳號\n\n以下是關於企業外幣繳款的詳細資訊：\n\n### 類型：虛擬帳號\n\n- **中國信託**\n  - 識別碼：95301\n  - SWIFT Code：CTCBTWTPXXX\n  - 承辦分行：城中分行\n  - 繳款書：Y\n  - 表單：X\n  - 自行繳款：0元\n  - 跨行匯款：依銀行規定\n\n- **兆豐銀行**\n  - 識別碼：88601\n  - SWIFT Code：ICBCTWTP\n  - 承辦分行：城中分行\n  - 繳款書：Y\n  - 表單：X\n  - 自行繳款：0元\n  - 跨行匯款：依銀行規定\n\n- **第一銀行**\n  - 識別碼：12101\n  - SWIFT Code：FCBKTWTP\n  - 承辦分行：建成分行\n  - 繳款書：Y\n  - 表單：X\n  - 自行繳款：新台幣100元\n  - 跨行匯款：依銀行規定\n\n- **彰化銀行**\n  - 識別碼：90558\n  - SWIFT Code：CCBCTWTP\n  - 承辦分行：總部\n  - 繳款書：Y\n  - 表單：X\n  - 自行繳款：0元\n  - 跨行匯款：依銀行規定\n\n- **台新銀行**\n  - 識別碼：96116\n  - SWIFT Code：TSIBTWTP\n  - 承辦分行：建北分行\n  - 繳款書：Y\n  - 表單：X\n  - 自行繳款：0元\n  - 跨行匯款：依銀行規定\n\n- **元大銀行**\n  - 識別碼：98373\n  - SWIFT Code：APBKTWTH\n  - 承辦分行：城中分行\n  - 繳款書：Y\n  - 表單：X\n  - 自行繳款：0元\n  - 跨行匯款：依銀行規定\n\n- **永豐銀行**\n  - 識別碼：80181\n  - SWIFT Code：SINOTWTP\n  - 承辦分行：營業部\n  - 繳款書：Y\n  - 表單：X\n  - 自行繳款：0元\n  - 跨行匯款：無跨行服務\n\n- **匯豐銀行（美金）**\n  - 識別碼：70171\n  - SWIFT Code：HSBCTWTP\n  - 承辦分行：匯豐（台灣）\n  - 繳款書：○\n  - 表單：自行轉帳申請書\n  - 自行繳款：0元\n  - 跨行匯款：依銀行規定\n\n- **華南銀行**\n  - 識別碼：95240\n  - SWIFT Code：HNBKTWTP\n  - 承辦分行：營業部\n  - 繳款書：○\n  - 表單：匯出匯款申請書\n  - 自行繳款：0元\n  - 跨行匯款：依銀行規定\n\n- **國泰世華**\n  - 識別碼：96373\n  - SWIFT Code：UWCBTWTP\n  - 承辦分行：館前分行\n  - 繳款書：○\n  - 表單：外匯活期存款取款憑條\n  - 自行繳款：0元\n  - 跨行匯款：無跨行服務\n\n- **合作金庫**\n  - 識別碼：92501\n  - SWIFT Code：TACBTWTP505\n  - 承辦分行：世貿分行\n  - 繳款書：○\n  - 表單：外匯存摺存款申請書\n  - 自行繳款：新台幣100元\n  - 跨行匯款：依銀行規定\n\n### 類型：實體帳號\n\n- **土地銀行營業部**\n  - 帳號：088101162189\n  - 摘要請填寫要保人姓名或ID\n  - 表單：外匯活期存款存入憑條\n  - 自行繳款：保費萬分之五且最低新台幣200元最高新台幣800元\n  - 跨行匯款：X\n\n### 備註\n\n- 外幣繳款書欄位為Y：表示繳款文件為建議書產生之外幣繳款書，保戶不需再另填銀行任何文件。\n- 外幣繳款書欄位為○：表示外幣繳款書僅當銀行附件，需依銀行規定再填寫相關表單。'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 13}, page_content='(三) WEB立即繳費\n1. 保戶可透過全國繳費網平台繳納首期保險費，可以「非約定帳戶」或「晶片金融卡」\n(網路ATM)繳費。僅開放台幣保單且繳款人應為要保人。\n2. 網路ATM 繳費金額上限及操作流程：\n3. 使用立即繳費繳交首期保險費，應於「業務人員招攬報告書」是否為立即繳欄位勾\n選為是，並填寫繳費日期。\n(四) 中信ATM繳費(操作方式詳官網)\n1. 至中信銀 ATM 自動櫃員機→點選繳費→選擇首期保費→輸入身分證統一編號及金\n額→確認完成交易。\n2. 繳費限額：單筆單次最高新台幣 200 萬元，當日累計不可超過新台幣 300 萬元，\n惟仍須視各銀行規定。\n3. 交易手續費：使用中國信託銀行金融卡不須支付手續費，它行金融卡則須支付跨行\n交易手續費。\n\n### 繳費方式與操作流程\n\n#### 非約定帳戶繳費\n\n**繳費金額上限**\n1. 當日累計最高新台幣 10 萬元。\n2. 每月同一帳戶累計最高新台幣 20 萬元。\n\n**操作流程**\n1. 登入台灣人壽官網→保戶服務→繳費服務→首期繳費→線上繳費→e-bill 首期立即繳費。\n2. 輸入身分證統一編號及驗證碼按送出。\n3. 輸入行動電話點選非約定銀行帳戶繳費。\n4. 輸入首期保險費金額按送出。\n5. 進入 e-Bill 全國繳費網→確認交易金額。\n6. 選擇轉出銀行及轉出帳號→驗證碼→確認付款。\n7. 確認完成交易。\n\n#### 晶片金融卡繳費\n\n**繳費金額上限**\n1. 單筆單次最高新台幣 200 萬元。\n2. 當日累計不可超過新台幣 300 萬元。\n\n**操作流程**\n1. 登入台灣人壽官網→保戶服務→繳費服務→首期繳費→線上繳費→e-bill 首期立即繳費。\n2. 輸入身分證統一編號及驗證碼按送出。\n3. 輸入行動電話點選晶片金融卡繳款。\n4. 輸入首期保險費金額按送出。\n5. 進入 e-Bill 全國繳費網→確認交易金額及繳費方式。\n6. 驗證碼→確認付款。\n7. 輸入晶片卡密碼→驗證碼→確認轉出帳號。\n8. 確認付款→轉出銀行/交易金額→確認→完成轉帳。'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 14}, page_content='肆、 續期保險費繳交方式及相關規定\n一、 續期保險費-採金融機構轉帳作業\n(一) 續期保險費採金融機構轉帳作業應注意事項：\n1. 新契約投保時同時約定續期繳費方式，可於授權書上勾選「首期及續期保險費」、「續期保\n險費」，於本公司簽約金融機構或媒體交換自動轉帳業務金融機構所開立之活期帳戶約定\n扣款。\n2. 外幣保單限用本公司指定銀行之外幣帳號，指定銀行及適用幣別請參照企業網站-代收保\n費機構。\n3. 保費折扣：\n(1) 以金融機構轉帳繳交續期保險費，享有 1%之保費折扣。(相關規定依各險種投保規則\n辦理)\n(2) 投資型商品、原繳費方式已提供優惠者及保單借款利息等不適用。\n4. 集體彙繳保件續期繳費變更為非金融機構自動轉帳，則自變更後下一期開始不再享有集\n體彙繳費保費折扣。\n5. 保險公司及保單服務人員(含業務員、授權書建檔人員、核保人員等)，均應全面核對授權\n書填寫內容。相關規定請參照自動轉帳及信用卡付款授權書作業規範【加強身分驗證機\n制】。\n6. 繳費完成後，續期保險費送金單一律由本公司郵寄於保戶。\n(二) 申請續期繳費方式變更及注意事項說明：\n1. 申請繳費方式為金融機構轉帳或更換金融機構扣款帳號者，請於當期繳費日前 20 天提出\n書面申請，若未能於繳費日前 20 天前申請變更，則自下期應繳日起生效。各金融機構核\n印時間請參照各金融機構核印、扣款時間及相關規定。\n2. 以金融機構轉帳繳交續期保險費時，需符合限定授權人關係，請檢附「保險費暨保險單借\n款利息自動轉帳授權書」並檢附關係證明文件。(授權人為保單關係人可免檢附)相關規定\n請參照繳費方式及受理應檢附文件。\n3. 填寫「保險費暨保險單借款利息自動轉帳授權書」須注意台/外幣適用欄位。\n4. 要保人須於授權書要保人欄位簽章並須與要保書簽章相同，授權人須留存金融機構之印\n鑑或簽章樣式。\n5. 若欲以數位帳戶為扣款帳號者，請先洽詢開戶銀行是否可扣繳保費，並請至開戶銀行臨櫃\n留存印鑑，待核印成功便能授權扣款(土地銀行、合作金庫、第一銀行此三家銀行無法授\n權扣款)。\n(三) 終止自動轉帳授權：\n1. 需於保險費應繳日 7 天前填具「終止轉帳(信用卡)付款授權申請書」書面通知終止，逾期\n通知者，則自下期始生變更效力；公司電訪要保人確認後始執行終止作業。\n2. 台幣保單終止授權後，繳費方式即變更為自行繳費(含郵局劃撥、ATM 轉帳、統一/全家\n/OK/萊爾富超商繳費)。\n3. 外幣保單若終止授權後，繳費方式變更為自行繳費(限銀行匯款)。'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 15}, page_content='(四) 續期保險費金融機構轉帳扣款時程及規則：\n(五) 投資型商品依條款約定定期超額保險費時，每次繳交保險費皆需符合「投資型人壽保險商品\n死亡給付對保單帳戶價值之最低比率規範」如下表，每期保險費於列印繳費通知單時重新計\n算，其含當次繳費後之比率不得低於被保險人當時到達年齡應符合之最低比率，若不符合規\n範則當次不扣款(包含定期保險費/不定期保險費/目標保險費/超額保險費)。\n1. 保單生效日為109 年7月1 日(不含)以前\n2. 保單生效日為109 年7月1 日(含)以後\n\n被保險人到達年齡分為三個區間：0 歲~40 歲、41~70 歲、71 歲以上。對應的死亡給付與保單帳戶價值的比例分別為：0 歲~40 歲時，死亡給付÷保單帳戶價值≧130%；41~70 歲時，死亡給付÷保單帳戶價值≧115%；71 歲以上時，死亡給付÷保單帳戶價值≧101%。\n\n被保險人到達年齡與死亡給付÷保單帳戶價值的對應關係如下：\n\n- 0 歲~30 歲：死亡給付÷保單帳戶價值 ≧ 190%\n- 31 歲~40 歲：死亡給付÷保單帳戶價值 ≧ 160%\n- 41 歲~50 歲：死亡給付÷保單帳戶價值 ≧ 140%\n- 51 歲~60 歲：死亡給付÷保單帳戶價值 ≧ 120%\n- 61 歲~70 歲：死亡給付÷保單帳戶價值 ≧ 110%\n- 71 歲~90 歲：死亡給付÷保單帳戶價值 ≧ 102%\n- 91 歲以上：死亡給付÷保單帳戶價值 ≧ 100%\n- 其他：死亡給付÷保單帳戶價值 -\n\n### LSP 系統進件\n\n#### 項目\n\n- 保單號碼為 10 碼且為 00、02、06、09、60 開頭之保單\n\n#### 前月26日~\n\n- 應繳日期：當月31日\n- 扣款日期：次月7日扣款\n- 扣款次數：無\n- 保費折扣：無\n- 送金單：無\n- 失敗通知：\n  - 第一次扣款失敗時寄出催告+簡訊通知\n  - 第二次扣款失敗時寄出簡訊通知\n  - 最後一次扣款失敗時寄出簡訊通知，同時提供 WEB 立即繳 URL 連結(僅適用台幣傳統型保單)\n\n### VLIFE/LIS 系統進件\n\n#### 項目\n\n- 保單號碼非屬右述編碼之保單\n\n#### 前月26日~\n\n- 應繳日期：當月10日\n- 扣款日期：當月10日午夜扣款，遇例假日順延。\n- 扣款次數：扣款至寬限期約3次。\n- 保費折扣：\n  - 台幣及外幣傳統型保單享1%折扣。\n  - 台幣及外幣投資型保單及借款利息無1%折扣。\n  - 實際轉帳折扣請參閱各險種投保規則。\n- 送金單：扣款後10個工作天後寄送。\n- 失敗通知：\n  - 第一次扣款失敗時寄出扣/請款未成功通知單\n  - 第二次扣款失敗時寄出簡訊通知\n  - 最後一次扣款失敗時寄出簡訊通知，同時提供 WEB 立即繳 URL 連結(僅適用台幣傳統型保單)\n\n#### 當月11日~\n\n- 應繳日期：當月25日\n- 扣款日期：當月25日午夜扣款\n- 扣款次數：無\n- 保費折扣：無\n- 送金單：無\n- 失敗通知：無\n\n#### 當月16日~\n\n- 應繳日期：當月15日\n- 扣款日期：當月22日扣款\n- 扣款次數：無\n- 保費折扣：無\n- 送金單：無\n- 失敗通知：無'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 16}, page_content='二、 續期保險費-採信用卡扣款作業\n(一) 續期保險費採信用卡扣款作業應注意事項\n1. 凡持有 VISA、MASTER、JCB、AE 卡，可於新契約投保時同時約定續期繳費方式，授\n權書上勾選「首期及續期保險費」、「續期保險費」，本公司於約定日期進行信用卡扣款作\n業，保戶收到銀行信用卡繳款帳單於期限內繳款即可，公司於扣款成功後 10 個工作天後\n寄送送金單。\n2. 依強化保險業透過信用卡或金融機構轉帳扣款收取保險費之身份驗證機制，保險公司及\n保單服務人員(含業務員、授權書建檔人員、核保人員等)，均應全面核對要保人簽章、授\n權人簽名、信用卡卡號/有效期限/姓名/身分證統一編號。相關規定請參照自動轉帳及信用\n卡付款授權書作業規範【加強身分驗證機制】。\n3. 信用卡卡號及授權人身分證統一編號須送「信用卡輔助持卡人身分驗證平台」，經驗證成\n功，始得進行續期保險費扣款作業。\n4. 保費折扣：\n以信用卡繳交續期保險費，無保費折扣適用規定依各險種投保規則辦理。\n5. 一張保單號碼限使用一張信用卡繳費。\n6. 外幣保單繳費方式不得變更為信用卡扣款。\n7. 繳費完成後，續期保險費送金單一律由本公司郵寄於保戶。\n(二) 申請續期繳費方式變更及注意事項說明：\n1. 變更繳費方式為信用卡繳費或更換信用卡卡號者，請於當期繳費日前 20 天提出書面申\n請，若未能於繳費日前 20 天前申請變更，則自下期應繳日起生效。\n2. 以信用卡繳交續期保險費時，需符合限定授權人關係，請檢附「保險費信用卡付款授權\n書」並檢附關係證明文件。(授權人為保單關係人可免檢附)相關規定請參照繳費方式及受\n理應檢附文件。\n3. 要保人須於授權書要保人欄位簽章並須與要保書簽章相同，授權人應留存信用卡上之簽\n名樣式。\n(三) 信用卡有效期限更改：信用卡有效期限到期，請要保人立即通知本公司或登入本公司會員網\n站-網路會員專區(保戶的家)進行線上變更，因效期扣款失敗請立即電洽本公司客服專線\n0800-099-850/(02)8170-5156。\n(四) 終止信用卡扣款授權：\n1. 需於保險費應繳日 7 天前填具「終止轉帳(信用卡)付款授權申請書」書面通知終止，逾期\n通知者，則自下期始生變更效力；公司電訪要保人確認後始執行終止作業。\n2. 終止授權後，繳費方式即變更為自行繳費(含郵局劃撥、ATM轉帳、統一/全家/OK/萊爾富\n超商繳費)。'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 17}, page_content='(五) 續期保險費信用卡扣款時程及規則:\n\n### LSP 系統進件\n\n#### 項目\n\n- 保單號碼為10碼，且為00、02、06、09、60開頭之保單。\n\n#### 應繳日期\n\n- 前月24日~當月9日\n- 前月26日~當月6日\n- 當月16日\n\n#### 扣款日期\n\n- 當月8日午夜\n- 當月23日午夜\n- 當月5日\n- 當月15日\n- 當月25日\n- 遇例假日順延。\n\n#### 扣款次數\n\n- 扣款至寬限期約3次。\n\n#### 保費折扣\n\n- 無保費折扣。(請參閱各險種投保規則)\n\n#### 失敗通知\n\n- 催告寄送時間：應繳費日+25天掛號寄出\n- 第一次扣款失敗：扣/請款未成功通知單\n- 第二次扣款失敗：簡訊通知\n- 最後一次扣款失敗：簡訊通知，同時提供WEB立即繳URL連結(僅適用台幣傳統型保單)。\n\n### VLIFE/LIS 系統進件\n\n#### 項目\n\n- 保單號碼非屬右述編碼之保單。\n\n#### 應繳日期\n\n- 當月8日\n- 當月23日\n- 當月5日\n- 當月15日\n- 當月25日\n\n#### 扣款日期\n\n- 當月8日午夜\n- 當月23日午夜\n- 當月5日\n- 當月15日\n- 當月25日\n- 遇例假日順延。\n\n#### 扣款次數\n\n- 扣款至寬限期約3次。\n\n#### 保費折扣\n\n- 無保費折扣。(請參閱各險種投保規則)\n\n#### 失敗通知\n\n- 第二次扣款失敗時寄出\n- 第一次扣款失敗：簡訊通知\n- 第二次扣款失敗：催告+簡訊通知\n- 最後一次扣款失敗：簡訊通知，同時提供WEB立即繳URL連結(僅適用台幣傳統型保單)。'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 18}, page_content='三、 續期保險費-採自行繳費作業\n(一) 續期保險費採自行繳費應注意事項\n1. 自行繳費通知單：每月約 25 日寄發次月「繳費通知單」，保戶可採以下任一繳費管道繳\n交續期保險費。\n2. 外幣保單請依「繳費通知單」上「應繳保險費」之金額「全額到匯」公司指定銀行之收款\n帳號，避免保險費匯款金額不足。\n3. 繳費完成後，續期保險費送金單一律由本公司郵寄於保戶。\n4. 未繳費通知：\n(二) 續期保險費繳費管道\n\n### VLIFE/LIS 系統進件\n\n**催告寄送時間**：應繳費日+25 天掛號寄出\n\n**將屆寬限期**：簡訊通知\n\n### LSP 系統進件\n\n**催告寄送時間**：應繳費日+20 天掛號寄出\n\n**將屆寬限期**：簡訊通知\n\n*註：VLIFE/LIS 系統進件包含宏利CAS 系統*\n\n### 繳費管道及相關規定\n\n#### 便利商店\n1. 繳交保險費金額限新台幣50,000元(不含)以下。\n2. 持本公司繳費通知單至全台7-11、全家、OK、萊爾富等便利商店繳納。\n3. 無保險費通知單者，可透過「網路會員專區」或「多元繳費專區」查詢超商繳費條碼。（查詢繳費條碼僅開放繳費方式為「自行繳費」之傳統型及保單號碼為9開頭之投資型保單使用）。\n\n#### Ibon繳費\n1. 繳交保險費金額限新台幣50,000元(不含)以下。\n2. 開放保單號碼為10碼且為00、02、06、09、60、90開頭之傳統型台幣保單使用。\n\n#### 郵局特戶\n1. 不限繳交保險費金額。\n2. 持本公司繳費通知單至郵局繳納。\n\n#### 中信ATM繳費\n1. 適用傳統型台幣商品。\n2. 至全台中信ATM繳費專區進行繳費，可依需求選擇多筆保單一次繳款或特定保單繳款。\n3. 繳交保險費金額上限同設定約定轉帳帳號。(約定轉帳限額：單筆單次最高新台幣200萬元，當日累計不可超過新台幣300萬元，惟仍須視各銀行規定)。\n\n#### 網路/ATM轉帳\n1. 限台幣保單使用。\n2. 依「保險費通知單」上所列示之轉帳帳號進行繳費。\n3. 單筆/單日轉帳限額最高為3萬元。(依各家銀行規定為準)\n4. 無保險費通知單者，可透過「網路會員專區」或「多元繳費專區」查詢專屬帳號。（查詢帳號僅開放繳費方式為「自行繳費」之傳統型及保單號碼為9開頭之投資型保單使用）。\n\n#### 活期帳戶扣款\n1. 需登入「網路會員專區」或點選繳費連結「多元繳費專區」進行繳費【註】。\n2. 僅開放繳費方式為「自行繳費」之傳統型台幣保單。\n3. 當日累計最高新台幣10萬元，每月同一帳戶累計最高20萬。\n\n#### 晶片金融卡繳費\n1. 需登入「網路會員專區」或點選繳費連結「多元繳費專區」進行繳費【註】。\n2. 僅開放繳費方式為「自行繳費」之傳統型台幣保單。\n3. 單筆單次最高新台幣200萬元，當日累計不可超過新台幣300萬元。\n\n#### 線上信用卡繳費\n1. 需登入「網路會員專區」或點選繳費連結「多元繳費專區」進行繳費【註】。\n2. 僅開放繳費方式為「自行繳費」之傳統型台幣保單。\n3. 信用卡持卡人限要保人本人。(美國運通卡不適用)。\n\n【註】操作流程請詳官網:(請參照保戶服務→繳費服務→自行繳費)'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 19}, page_content='(三) 續期保險費自行匯款帳號- VLIFE/LIS 系統\n※ 台幣續期保險費依轄屬分公司匯入以下指定台幣實體帳號。\n※ 外幣續期保險費匯款帳號\n\n### 匯款資訊\n\n- **匯款戶名**: TAIWAN LIFE INSURANCE CO.,LTD.\n- **匯款銀行**: CTBC Bank Co.,Ltd.\n- **虛擬帳號**: 95303+保單號碼10碼+檢查碼（共16碼）\n- **SWIFT CODE**: CTCBTWTPXXX\n\n### 注意事項\n\n1. 匯款單請載明『繳費用途』、『要保人姓名』、『保單號碼』及『應繳日期』。\n2. 匯款後請傳真至(02)6603-1909客戶服務部-作業一科，傳真後請保戶來電客服專線0800-099-850協助確認。\n3. 虛擬帳號轉換碼：請電洽分公司、客服中心或上本公司會員網站-網路會員專區(保戶的家)查詢帳號轉換碼。\n\n以下是台灣人壽保險股份有限公司各分公司的匯款資訊：\n\n### 台北分公司\n- **匯款戶名**：台灣人壽保險股份有限公司 台北分公司\n- **匯款銀行**：中國信託商業銀行 城中分行\n- **匯款帳號**：822-107118347202\n- **劃撥帳號**：1185-1115\n\n### 新竹分公司\n- **匯款戶名**：台灣人壽保險股份有限公司 新竹分公司\n- **匯款銀行**：土地銀行 新竹分行\n- **匯款帳號**：005-016-001-035413\n- **劃撥帳號**：0110-3183\n\n### 台中分公司\n- **匯款戶名**：台灣人壽保險股份有限公司 台中分公司\n- **匯款銀行**：中國信託商業銀行 台中分行\n- **匯款帳號**：822-026540322963\n- **劃撥帳號**：0021-9012\n\n### 嘉義分公司\n- **匯款戶名**：台灣人壽保險股份有限公司\n- **匯款銀行**：合作金庫 北嘉義分行\n- **匯款帳號**：006-1520717100015\n- **劃撥帳號**：0035-3812\n\n### 台南分公司\n- **匯款戶名**：台灣人壽保險股份有限公司 台南分公司\n- **匯款銀行**：中國信託商業銀行 西台南分行\n- **匯款帳號**：822-222118015202\n- **劃撥帳號**：0031-1131\n\n### 高雄分公司\n- **匯款戶名**：台灣人壽保險股份有限公司 高雄分公司\n- **匯款銀行**：台灣中小企業銀行 三民分行\n- **匯款帳號**：050-87012125575\n- **劃撥帳號**：0041-3321\n\n### 東部分公司\n- **匯款戶名**：台灣人壽保險股份有限公司 東部分公司\n- **匯款銀行**：元大銀行 花蓮分行\n- **匯款帳號**：806-20962000018558\n- **劃撥帳號**：0643-0636'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 20}, page_content='(四) 續期保險費匯款帳號- LSP 系統\n※ 帳戶如下表：\n四、 高齡關懷電訪作業\n(一) 適用時間：授權書申請日/匯款日為民國 111年10 月01 日(含)起。\n(二) 若續期繳款人異動且新繳款人為高齡者，公司將於信用卡／銀行轉帳完成授權前或匯款入\n帳前，向高齡客戶進行電訪確認。\n\n外幣\n\n台幣，亦稱新台幣，是台灣的法定貨幣。其貨幣符號為NT$，ISO 4217貨幣代碼為TWD。\n\n台灣人壽保險股份有限公司 Taiwan Life Insurance Co., Ltd. 提供的匯款資訊如下：\n\n### 外幣匯款\n\n- **銀行代號**: 822\n- **銀行名稱**: 中國信託商業銀行 (CTBC Bank Co., Ltd.)\n- **SWIFT CODE**: CTCBTWTPXXX\n- **虛擬帳號**: 95265 + 保單號碼10碼 (共15碼)\n\n- **銀行代號**: 013\n- **銀行名稱**: 國泰世華銀行 (Cathay United Bank, Taipei, Taiwan)\n- **分行名稱**: 館前分行\n- **SWIFT CODE**: UWCBTWTP\n- **虛擬帳號**: 96201 + 要保人身分證統一編號後9碼 (共14碼)\n\n### 台幣匯款\n\n- **銀行代號**: 822\n- **銀行名稱**: 中國信託商業銀行\n- **分行名稱**: 城中分行\n- **虛擬帳號**: 502 + 保單號碼10碼 (共13碼) 或 要保人身分證統一編號後11碼 (共14碼) 含英文轉換碼\n\n- **銀行代號**: 822\n- **銀行名稱**: 中國信託商業銀行\n- **分行名稱**: 城中分行\n- **虛擬帳號**: 3562 (需電洽分公司、客服中心提供帳號轉換碼，可快速入帳)\n\n- **銀行代號**: 013\n- **銀行名稱**: 國泰世華銀行 (僅提供投資型保單及原宏利保單)\n- **分行名稱**: 館前分行\n- **虛擬帳號**: 8071 + 保單號碼10碼 (共14碼)【投資型】\n\n### 郵局劃撥\n\n- **劃撥帳號**: 50120507\n- **注意事項**: 首期保險費不適用，另請於劃撥單載明下列資訊：\n  1. 保單號碼\n  2. 要保人姓名\n  3. 繳費用途\n  4. 聯絡電話\n\n### 注意事項\n\n1. 匯款單須載明『保單號碼』、『要保人姓名』、『繳費用途』、『聯絡電話』。\n2. 為了保戶匯入款項可以即時銷帳避免延誤時效，由銀行匯入款項請務必傳真至 (02)6603-1909 至客戶服務二部-作業一科，傳真後請保戶來電客服專線 0800-099-850 協助確認。\n3. 增加客專受理傳真貼心服務：\n  - 服務範圍：續期保費相關匯款單 (首期保費不適用)。\n  - 檢附文件：匯款單 (須載明保單號碼、要保人姓名、繳費用途、聯絡電話)。\n  - 受理時間：下午3點前完成受理者，匯款單分兩批次傳真至客戶服務二部-作業一科於當日入帳 (逾3點受理者，列為次一工作日傳真件)。\n  - 傳真時間：第1批次早上11點、第2批次下午3點。\n  - 入帳查詢：業務人員於業務e平台查詢 (受理日T+1)。'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 21}, page_content='五、 續期保險費扣款不成通知方式\n續期保險費採信用卡、金融機構轉帳作業者，扣款不成通知方式如下：\n(一) 簡訊通知(簡訊發送內容及發出日)：'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 22}, page_content='(二) 紙本通知：\n1. VLIFE/LIS\n\n1. **第一次扣款失敗**：\n   - 平信寄出「扣/請款未成功通知單」。\n\n2. **第二次扣款失敗**：\n   - 於應繳日+25日，掛號寄出「保險費催告(繳費)通知書」。'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 23}, page_content='2. LSP'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 24}, page_content='伍、 各金融機構核印、扣款時間及相關規定\n一、 各金融機構核印平均作業天數請參考下表，實際天數仍需依各金融構實務作業為準，如有新\n增合作金融機構或調整作業頻率者，將配合更動。\n二、 續期保險費扣款時間，除配合合作銀行扣款時間外，另請參照續期保險費-金融機構轉帳扣\n款時程及規則。\n三、 金融機構轉帳核印及首期扣款時間表(未包含文件遞送及及公司內部作業天數)\n\n以下是各金融機構的扣款相關資訊：\n\n1. **郵局**\n   - 幣別：台幣\n   - 核印時間：7-10 天\n   - 首期扣款時間：每月7、15、22、27日。\n\n2. **中國信託**\n   - 幣別：台幣、外幣\n   - 核印時間：3-5 天\n   - 首期扣款時間：每一工作天。\n\n3. **華南銀行**\n   - 幣別：台幣、外幣\n   - 核印時間：5-7 天\n   - 首期扣款時間：每一工作天。\n\n4. **彰化銀行**\n   - 幣別：台幣、外幣\n   - 核印時間：3-5 天\n   - 首期扣款時間：每一工作天。\n\n5. **永豐銀行**\n   - 幣別：台幣、外幣\n   - 核印時間：3-5 天\n   - 首期扣款時間：每一工作天。\n\n6. **台新國際**\n   - 幣別：台幣、外幣\n   - 核印時間：3-5 天\n   - 首期扣款時間：每一工作天。\n\n7. **第一銀行**\n   - 幣別：台幣\n   - 核印時間：10-15 天\n   - 首期扣款時間：每一工作天(ACH)，遇假日順延。\n\n8. **台北富邦銀行**\n   - 幣別：台幣、外幣\n   - 核印時間：3-5 天\n   - 首期扣款時間：每週二次(每週二、每週四)，遇假日順延。\n\n9. **合作金庫**\n   - 幣別：台幣、外幣\n   - 核印時間：3-5 天\n   - 首期扣款時間：每週二次(每週二、每週四)，遇假日順延。\n\n10. **台灣企銀**\n    - 幣別：台幣、外幣\n    - 核印時間：3-5 天\n    - 首期扣款時間：每週二次(每週二、每週四)，遇假日順延。\n\n11. **台灣銀行**\n    - 幣別：台幣、外幣\n    - 核印時間：3-5 天\n    - 首期扣款時間：每週二次(每週二、每週四)，遇假日順延。\n\n12. **土地銀行**\n    - 幣別：台幣、外幣\n    - 核印時間：3-5 天\n    - 首期扣款時間：每週二次(每週二、每週四)，遇假日順延。\n\n13. **上海銀行**\n    - 幣別：台幣\n    - 核印時間：10-15 天\n    - 首期扣款時間：每一工作天(ACH)，遇假日順延。\n\n14. **國泰世華銀行**\n    - 幣別：台幣\n    - 核印時間：10-15 天\n    - 首期扣款時間：每一工作天(ACH)，遇假日順延。\n\n15. **高雄銀行**\n    - 幣別：台幣\n    - 核印時間：10-15 天\n    - 首期扣款時間：每一工作天(ACH)，遇假日順延。\n\n16. **兆豐國際商銀**\n    - 幣別：台幣\n    - 核印時間：10-15 天\n    - 首期扣款時間：每一工作天(ACH)，遇假日順延。\n\n17. **台中商銀**\n    - 幣別：台幣\n    - 核印時間：10-15 天\n    - 首期扣款時間：每一工作天(ACH)，遇假日順延。\n\n18. **京城商銀**\n    - 幣別：台幣、外幣\n    - 核印時間：10-15 天\n    - 首期扣款時間：每一工作天(ACH)，遇假日順延。\n    - 備註：全通路不適用人民幣。\n\n19. **匯豐(台灣)**\n    - 幣別：台幣、外幣\n    - 核印時間：10-15 天\n    - 首期扣款時間：每一工作天(ACH)，遇假日順延。\n    - 備註：全通路不適用澳幣及人民幣。\n\n20. **華泰銀行**\n    - 幣別：台幣\n    - 核印時間：10-15 天\n    - 首期扣款時間：每一工作天(ACH)，遇假日順延。'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 25}, page_content=''),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 26}, page_content='陸、 保單貸款還款息\n一、保單貸款之繳息通知\n\n### 系統別\n\n#### VLIFE/LIS 系統\n\n- **繳息方式**：\n  - **寄發時間**：每年2月、5月、8月、11月下旬寄出台/外幣「繳息通知單」。\n  - **台幣保單自行繳費**：\n    1. 保單借款利息繳息通知單【三合一】予保戶自行繳費。\n    2. 繳費方式：\n       - 全省中信ATM櫃員機\n       - 劃撥特戶19536523\n       - 便利商店條碼繳費\n  - **外幣保單自行繳費**：保單借款利息繳息通知單予保戶自行繳費，通知書揭露繳息匯款帳號。\n  - **台/外幣保單自動轉帳扣款次數**：固定於每年3月、6月、9月、12月之10日午夜扣款(遇例假日順延)，如扣款未成，當月25日午夜再行扣款一次(遇例假日順延)，如仍扣款未成，其利息累計至次一自動轉帳基準日再進行扣款，但若逾保單借款週年日，則依保單借款約定辦理。\n\n#### LSP 系統\n\n- **繳息方式**：\n  - **寄發時間**：保單週年日翌日寄發「繳息通知單」。\n  - **台幣保單自行繳費**：\n    1. 保單借款利息繳息通知單【三合一】予保戶自行繳費。\n    2. 繳費方式：\n       - 全省中信ATM櫃員機\n       - 劃撥特戶19536523\n       - 便利商店條碼繳費\n       - ibon列印繳費專區-(利息)限保單週年日+14工作天內可用此方式\n  - **外幣保單自行繳費**：保單週年日翌日寄發「保單借款利息繳納通知書」，通知書揭露繳息匯款帳號。\n  - **台/外幣保單自動轉帳扣款次數**：無開放自動轉帳。'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 27}, page_content='二、 保單借款之還款息帳號\n\n以下是各地區分公司的郵局劃撥帳號資訊：\n\n1. 台北分公司：郵局劃撥帳號為11851115。\n2. 新竹分公司：郵局劃撥帳號為01103183。\n3. 台中分公司：郵局劃撥帳號為00219012。\n4. 嘉義分公司：郵局劃撥帳號為00353812。\n5. 台南分公司：郵局劃撥帳號為00311131。\n6. 高雄分公司：郵局劃撥帳號為00413321。\n7. 東部分公司：郵局劃撥帳號為06430636。\n\n### 系統別\n\n- **VLIFE/LIS**\n- **LSP**: 保單號碼為 10 碼\n\n### 適用保單\n\n- **VLIFE/LIS**: 保單號碼非屬右述編碼之保單\n- **LSP**: 且為00、02、06、09、60 開頭之保單\n\n### 本金及利息還款帳號\n\n#### 台幣保單\n\n- **臨櫃**: 親自至本公司各地分公司服務櫃檯辦理還款。\n- **郵局劃撥**: 至郵局劃撥至本公司各地分公司之劃撥帳號：\n  - 台北: 11851115\n  - 新竹: 01103183\n  - 台中: 00219012\n  - 嘉義: 00353812\n  - 台南: 00311131\n  - 高雄: 00413321\n  - 東部: 06430636\n- **郵局劃撥**: 至郵局劃撥至本公司之郵政劃撥帳號：50120507。\n- **匯款**: 依轄屬分公司本公司各地分公司之指定\n  - 匯款銀行：822 中國信託商業銀行城中分行\n  - 匯入帳號：3562+1 碼(類別)+10 碼(保單號碼)+1 碼(檢核碼)共計16 碼\n- **台幣實體帳號**\n\n#### 外幣保單\n\n- **匯款**: \n  - 匯款銀行：CTBC Bank Co.,Ltd(中國信託銀行)\n  - 戶名：台灣人壽保險股份有限公司\n  - SWIFT CODE：CTCBTWTPXXX\n  - 虛擬帳號：95432+保單號碼10 碼+檢查碼(共16 碼)\n- **匯款**: \n  - 匯款銀行：CTBC Bank Co.,Ltd(中國信託銀行)\n  - 戶名：台灣人壽保險股份有限公司\n  - SWIFT CODE：CTCBTWTPXXX\n  - 匯入帳號：95265+保單號碼10 碼(共15碼)\n\n### 註\n\n1. 請於劃撥單通訊欄中/匯款單載明保單號碼、要保人姓名、聯絡電話及借款/墊繳本息各自清償金額。\n2. 虛擬帳號轉換碼：請電洽本公司客服專線 0800-099-850/(02)8170-5156 或上本公司會員網站-網路會員專區(保戶的家)查詢。\n3. 保戶須自行負擔匯款手續費。\n4. 繳款人限保單關係人，如非保單關係人，需於繳費後檢附身分/關係證明文件影本，與匯款單影本一併傳真至(02)6603-1909，傳真後請電洽客戶服務二部作業一科確認。相關規定請參照繳費方式及受理應檢附文件。\n5. 繳費完成後，還款收據一律由本公司郵寄於保戶。'),
#   Document(metadata={'source': '../data/個人保險首續期繳費暨保單貸款還款息作業手冊(113年7月版)_業務通路版.pdf', 'page_number': 28}, page_content='柒、 行動保全續期保費服務說明(僅適用業務通路)\n\n# 步驟說明\n\n## 一、 服務項目\n\n1. 續期保費信用卡授權\n2. 續期保費信用卡效期變更\n3. 續期保費信用卡終止授權\n\n## 二、 文件簽署\n\n(確認使用 IPAD 申請保全服務)\n\n1. 簽署紙本「行動投保系統確認同意書」後，始得以線上簽名方式簽署要保文件。\n2. 可採一次性密碼(OTP)驗證：首次申請 OTP 驗證成功+保全變更成功+電訪成功後，下次申請保全服務時開始可以 OTP 驗證方式取代簽署紙本「行動保全系統確認同意書暨 OTP 驗證申請書」。\n\n註：保戶使用行動保全申請保全服務之驗證方式，請詳「個人保險保單服務暨契約變更手冊」。\n\n## 三、 拍照上傳\n\n1. 拍照「台灣人壽行動保全系統確認同意書暨 OTP 驗證申請書」後，以附件方式上傳並於 1 個工作天內繳回正本，逾期繳回，則予以退件。若 OTP 驗證申請成功自下次申請保全服務時可免檢附。\n2. 文件拍照上傳時，務必清楚及完整。若內容有誤、不完整或不清楚，將照會補全。\n3. 依繳款人相關規定應檢附文件者，併同「行動保全系統確認同意書暨 OTP 驗證申請書」正本繳回。\n\n## 四、 簡訊通知\n\n成功送件後及申請作業結案後，傳送簡訊至保戶留存公司之手機號碼。\n\n## 五、 電訪作業\n\n1. 申請「續期保費信用卡終止授權」項目，將電訪要保人進行確認。\n2. 首次申請 OTP 驗證或申請 OTP 驗證後透過「行動保全」變更行動電話者，須另完成電訪作業。')]]

# %%
'''將表格的描述加入到該頁結尾'''
from typing import List, Optional
from pydantic import BaseModel, Field
from langchain_core.prompts import ChatPromptTemplate
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import traceback

class QuestionAnswer(BaseModel):
    question: str = Field(
        description="客戶提出的問題"
    )
    answer: str = Field(
        description="相對應的答案"
    )
    
class QuestionAnswerPack(BaseModel):
    question_answers: Optional[List[QuestionAnswer]] = Field(
        description="客戶可能提出的問題與答案清單"
    )
prompt = ChatPromptTemplate.from_messages([
    (
        "system",
"""你是一個客戶服務問答專家，根據提供的資訊，提供客戶可能提的問題，以及相對應的答案，
如果提供的資訊不足以產生問答，不要捏造任何未提供的資訊，你可以縮小問答數量來提供正確的資訊
"""
    ),
    (
        "human",
        """請根據參考內容，模擬客戶可能會問的問題與答案，提供 {question_num} 個問答\n\n提供的資訊:\n{ref_str}""",
    ),
])
desc_llm = llm.with_structured_output(
    QuestionAnswerPack
)
desc_chain = prompt | desc_llm

def qa_generator(question_num: int, ref_str: str):
    try:
        if question_num > 50:
            question_num = 50
        if question_num < 1:
            question_num = 1
        qas = desc_chain.invoke({"ref_str": ref_str, "question_num": question_num}).question_answers
        if not qas:
            return []
        return qas
    except Exception as e:
        logging.error(e)
        logging.error(traceback.format_exc())
        return []

# %%
qas = qa_generator(10, pages[0][3])
qas
# Out:
# [QuestionAnswer(question='保險業務員可以代收保戶的保險費嗎？', answer='根據規定，保險業務員不得代收保戶的保險費，包括現金、支票等形式的繳納。'),
#  QuestionAnswer(question='新契約的保險什麼時候生效？', answer='新契約投保於核保通過且繳交首期保險費後，保險才會生效。'),
#  QuestionAnswer(question='續期保險費的繳納方式可以變更嗎？', answer='續期繳費方式可以隨時申請變更，但需在應繳費日前20天申請並檢附相關授權書。'),
#  QuestionAnswer(question='有哪些繳費方式？', answer='繳費方式有躉繳、分期繳（月繳、季繳、半年繳、年繳）和彈性繳（適用於超額保險費）。'),
#  QuestionAnswer(question='月繳件首期應繳交多少保險費？', answer='月繳件首期應繳交2個月的保險費，除非商品或特定通路另有規定。'),
#  QuestionAnswer(question='保單生效日期可以溯前嗎？', answer='根據主管機關函令，保單生效日期不得溯前。'),
#  QuestionAnswer(question='傳統型商品的繳別因子是多少？', answer='傳統型商品的繳別因子為：半年繳0.520，季繳0.262，月繳0.088。'),
#  QuestionAnswer(question='投資型商品的繳別因子需要換算嗎？', answer='投資型商品的目標保險採分期繳納者，無須依繳別係數換算。'),
#  QuestionAnswer(question='附約的繳費方式與主約相同嗎？', answer='原則上，附約的繳費方式與主約相同，但若商品另有規定則除外。'),
#  QuestionAnswer(question='信用卡扣款需要什麼手續？', answer='信用卡扣款作業須完成信用卡身份驗證機制，並需檢附「保險費信用卡付款授權書」。')]

# %%
from typing import Dict
from concurrent.futures import Future

qa_num = 10
futures = []
future_map: Dict[Future, Document] = {}

qas: List[QuestionAnswer] = []
with ThreadPoolExecutor(max_workers=5) as executor:
    for doc_pages in pages:
        for page in doc_pages:
            future = executor.submit(qa_generator, qa_num, page.page_content)
            futures.append(future)
            future_map[future] = page
    for future in tqdm(
        as_completed(futures), total=len(future_map), desc="Processing documents"
    ):
        try:
            qas += future.result()
        except Exception as e:
            logging.error(f"error: {e}, page_content: {future_map[future].page_content}")
            logging.error(traceback.format_exc())
# Out:
# 什麼是保險？
# 保險是一種風險管理工具，通過支付保費，您可以在發生特定事件時獲得經濟補償。
# ----------------------------------------
# 我需要什麼類型的保險？
# 這取決於您的個人情況和需求。常見的保險類型包括健康保險、人壽保險、汽車保險和房屋保險。
# ----------------------------------------
# 保險費用如何計算？
# 保險費用根據多種因素計算，包括您的年齡、健康狀況、保險類型和保額等。
# ----------------------------------------
# 如何申請保險理賠？
# 您需要聯繫您的保險公司，提供相關文件和證據，如醫療報告、警察報告等，然後按照指示完成理賠申請。
# ----------------------------------------
# 保險的等待期是什麼？
# 等待期是指從保單生效到可以提出理賠申請的時間段。在此期間內發生的事件通常不在保險範圍內。
# ----------------------------------------
# 什麼是免賠額？
# 免賠額是指在保險公司開始支付理賠之前，您需要自行承擔的費用。
# ----------------------------------------
# 保險的保額是什麼意思？
# 保額是指保險公司在發生保險事故時，根據保單條款所支付的最高金額。
# ----------------------------------------
# 我可以取消保險嗎？
# 是的，您可以隨時取消保險，但可能會有一些手續費或損失部分已支付的保費。
# ----------------------------------------
# 保險公司如何評估風險？
# 保險公司通過分析多種因素來評估風險，包括您的年齡、健康狀況、職業、生活習慣等。
# ----------------------------------------
# 什麼是保險的除外責任？
# 除外責任是指保單中明確列出的不在保險範圍內的情況或事件。
# ----------------------------------------
